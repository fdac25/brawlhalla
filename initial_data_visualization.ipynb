# %% [markdown]
# <a href="https://colab.research.google.com/github/fdac25/brawlhalla/blob/main/initial_data_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notebook For Displaying Early Versions Of Our Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("brawlhalla_matches.csv")

data
# Out:
#        match_id        date  year                          tournament_name  \
# 0      67322836  2023-11-03  2023  Brawlhalla World Championship Expo 2023
# 1      67322820  2023-11-03  2023  Brawlhalla World Championship Expo 2023
# 2      67322818  2023-11-03  2023  Brawlhalla World Championship Expo 2023
# 3      67317310  2023-11-03  2023  Brawlhalla World Championship Expo 2023
# 4      67317302  2023-11-03  2023  Brawlhalla World Championship Expo 2023
# ...         ...         ...   ...                                      ...
# 12526  55581728  2023-01-05  2023                     Galaxy Cup: Blizzard
# 12527  55581357  2023-01-05  2023                     Galaxy Cup: Blizzard
# 12528  55581333  2023-01-05  2023                     Galaxy Cup: Blizzard
# 12529  55581290  2023-01-05  2023                     Galaxy Cup: Blizzard
# 12530  55581203  2023-01-05  2023                     Galaxy Cup: Blizzard
#
#       event_name is_official    player_1_name  player_1_smash_id  \
# ...

# %%
x = np.random.normal(170, 10, 250) # normal distribution

plt.hist(x)
plt.show()

# %%
# data.sort_values(by='date', inplace=True)
data['tournament_name'].value_counts().plot(kind='bar', figsize=(22, 6))
plt.xlabel('Tournament')
plt.ylabel('# Of Matches')
plt.title('Matches Per Tournament')
plt.show()
